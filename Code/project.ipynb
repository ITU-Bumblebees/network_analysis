# %% [markdown]
# # Project

# %% [markdown]
# #### For this project we will start by importing the necessary libraries

# %%
# !pip install pyvis
# Out:
# Requirement already satisfied: pyvis in /root/venv/lib/python3.9/site-packages (0.3.1)
# Requirement already satisfied: networkx>=1.11 in /root/venv/lib/python3.9/site-packages (from pyvis) (2.8.8)
# Requirement already satisfied: jinja2>=2.9.6 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pyvis) (2.11.3)
# Requirement already satisfied: ipython>=5.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pyvis) (8.5.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /root/venv/lib/python3.9/site-packages (from pyvis) (2.2.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (2.13.0)
# Requirement already satisfied: traitlets>=5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.5.0)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: stack-data in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.5.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (3.0.31)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.17.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2>=2.9.6->pyvis) (2.0.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: executing in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.1.1)
# Requirement already satisfied: asttokens in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.8)
# Requirement already satisfied: pure-eval in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import os

import networkx as nx
from networkx.algorithms import bipartite 

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
from matplotlib.colors import ListedColormap
import seaborn as sns
from pyvis.network import Network 

from main import GraphAnalysis

# %%
#pip install decorator==4.3

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
savefigs = True
if savefigs:
    if not os.path.isdir('../figs'):
        os.makedirs('../figs')

# %% [markdown]
# ##### Now we will import the csv files to start working with the data

# %%
#First we need to get the data from the csv file, made into a data frame
attributes= pd.read_csv('../Data/nodeattribute.csv', delimiter=';')
edgelist= pd.read_csv('../Data/edgelist.csv',delimiter=';')
g_attributes= attributes[attributes['0']=='gene']
d_attributes = attributes[attributes['0']=='disease']


#We need to convert the data frame into a dictionary to use the set_node_attributes 
nodes_attr = attributes.set_index('Id').to_dict(orient='index')
g_nodes_attr = g_attributes.set_index('Id').to_dict(orient='index')
d_nodes_attr= d_attributes.set_index('Id').to_dict(orient='index')


#Made it into a list
g_nodes= g_attributes['Id'].to_list()
d_nodes=d_attributes['Id'].to_list()
edges= edgelist.values.tolist()


G = nx.Graph()
G.add_nodes_from(g_nodes, bipartite=0)
G.add_nodes_from(d_nodes, bipartite=1)
nx.set_node_attributes(G, nodes_attr)
G.add_edges_from(edges)

print(d_nodes)

#bottom_nodes, top_nodes = bipartite.sets(G)
# Out:
# [55, 47, 114, 45, 87, 54, 81, 48, 70, 137, 223, 390, 220, 325, 68, 208, 213, 30, 65, 139, 185, 202, 302, 364, 634, 53, 86, 99, 117, 155, 41, 59, 130, 239, 285, 640, 63, 125, 197, 224, 236, 414, 420, 448, 822, 42, 110, 122, 140, 146, 186, 266, 324, 332, 411, 775, 37, 120, 222, 306, 367, 541, 751, 786, 44, 74, 109, 164, 187, 200, 215, 219, 245, 327, 384, 607, 661, 736, 778, 940, 80, 119, 121, 123, 133, 158, 180, 199, 203, 235, 237, 248, 277, 280, 290, 314, 340, 369, 401, 419, 423, 429, 441, 447, 474, 497, 570, 602, 782, 790, 851, 938, 968, 43, 78, 79, 101, 113, 118, 132, 165, 177, 189, 201, 216, 226, 227, 270, 282, 292, 328, 402, 464, 467, 527, 560, 574, 671, 703, 742, 744, 795, 796, 856, 880, 919, 953, 984, 985, 36, 38, 46, 100, 126, 128, 131, 154, 156, 181, 191, 192, 209, 210, 211, 217, 238, 272, 286, 287, 307, 322, 323, 331, 341, 370, 385, 408, 417, 426, 446, 454, 457, 463, 466, 470, 471, 472, 476, 483, 484, 485, 491, 493, 526, 545, 550, 559, 575, 616, 681, 682, 685, 691, 692, 765, 767, 772, 773, 779, 784, 785, 793, 797, 799, 814, 815, 838, 853, 858, 873, 930, 963, 982, 1048, 1050, 1053, 1061, 1067, 1070, 1145, 1245, 39, 62, 69, 76, 77, 98, 112, 115, 116, 124, 127, 129, 134, 136, 138, 147, 157, 166, 167, 184, 188, 198, 212, 218, 225, 228, 229, 231, 232, 249, 252, 253, 283, 284, 288, 289, 291, 293, 294, 301, 303, 304, 305, 310, 311, 312, 313, 316, 317, 334, 342, 363, 365, 366, 368, 374, 375, 376, 380, 386, 403, 404, 405, 406, 407, 409, 415, 416, 422, 424, 425, 434, 442, 453, 455, 456, 468, 473, 475, 477, 478, 479, 480, 481, 482, 486, 490, 492, 502, 503, 523, 524, 535, 536, 540, 542, 552, 553, 554, 555, 556, 557, 558, 563, 576, 577, 578, 579, 585, 605, 606, 608, 627, 633, 637, 643, 644, 645, 663, 664, 665, 667, 668, 669, 670, 680, 686, 687, 689, 693, 694, 695, 701, 702, 704, 709, 716, 743, 745, 746, 747, 748, 752, 753, 754, 766, 769, 770, 771, 774, 781, 792, 794, 798, 810, 816, 817, 818, 819, 820, 826, 828, 829, 833, 834, 835, 836, 841, 842, 852, 868, 871, 872, 874, 875, 876, 877, 878, 879, 882, 883, 884, 887, 888, 889, 897, 902, 904, 909, 911, 912, 923, 924, 925, 928, 929, 935, 939, 941, 942, 943, 944, 947, 948, 949, 954, 955, 956, 958, 959, 960, 961, 962, 965, 966, 969, 974, 975, 976, 977, 978, 979, 980, 986, 987, 991, 996, 1002, 1003, 1012, 1015, 1016, 1020, 1025, 1027, 1029, 1033, 1034, 1040, 1047, 1051, 1065, 1066, 1068, 1069, 1072, 1073, 1078, 1080, 1081, 1082, 1089, 1091, 1092, 1094, 1099, 1100, 1101, 1102, 1120, 1121, 1130, 1132, 1136, 1148, 1152, 1153, 1174, 1181, 1198, 1208, 1221, 1227, 1228, 1232, 1238, 1242, 1270, 1285, 1289, 1303, 1304, 1305, 1306, 1307]

# %%
#Checking that the code worked properly
G.nodes()
#G.edges()
#G.nodes[55]["Label"]
#nodes_attr"""

G.nodes[117]['bipartite']
# Out:
# 1

# %% [markdown]
# In order to start working with the graph we need to make sure it is connected

# %%
print(nx.is_connected(G))
print(nx.is_bipartite(G))
# Out:
# True
# True

# %% [markdown]
# ### Project description
# 1. Basic network description of your data (what type of network it is, what does it represent, is it real or synthetically generated, etc). In practice, the result of project phase #1 (finding data).

# %% [markdown]
# It is a unipartite, undirected and unweighted network that describes the associations between human diseases and human genes, as extracted from the Morbid Map (MM) of the Online Mendelian Inheritance in Man (OMIM) in 2005.
#
# Source : https://github.com/gephi/gephi/wiki/Datasets

# %% [markdown]
# 2. Basic network statistics of your data (number of nodes, edges, clustering, degree distribution, etc). In practice, the result of project phase #2 (exploratory data analysis)

# %%
#Graph properties 
"""
nx.is_directed(G)
nx.is_bipartite(G)
ns.is_weighted(G)

"""

#the number of nodes and egdes
num_nodes = len(G.nodes())
num_genes= len(g_nodes)
num_diseases= len(d_nodes) 
num_edges= len(G.edges())

#Printing the num of nodes and edges
print(f'The number of nodes that are genes is: {num_genes}\nThe number of nodes that are diseases is: {num_diseases}\n---\nThe total number of nodes is: {num_nodes} ')
print(f'\n---\nThe number of edges is: {num_edges}')
# Out:
# The number of nodes that are genes is: 903
# The number of nodes that are diseases is: 516
# ---
# The total number of nodes is: 1419
#
# ---
# The number of edges is: 1550

# %%
def make_df(column2, function, graph):
    df = pd.DataFrame(list(function(graph).items()), columns=['Id', column2])
    df.set_index('Id', inplace=True)

    return df

closeness = make_df('closeness', nx.closeness_centrality, G)
degree_centrality = make_df('degree', nx.degree_centrality, G)

df= degree_centrality.join(closeness, on='Id')

#density 
density = nx.density(G)

# %% [markdown]
# #### Clustering

# %%
#global clustering coefficient
print(nx.transitivity(G))

#average clustering coefficient
print(nx.average_clustering(G))

#local clustering coefficient
#print(nx.clustering(G))
# Out:
# 0
# 0.0

# %% [markdown]
# #### Degree Distribution

# %%
degree_freq = nx.degree_histogram(G)
fig, ax = plt.subplots()

sns.histplot(degree_freq, color = '#826fc9', bins = 30, ax = ax)
ax.set(title = 'Degree distribution', xlabel = 'Degree', ylabel = 'Frequency');

if savefigs:
    plt.savefig('../figs/DegreeDistribution.png', bbox_inches = 'tight')

# %%
degree_freq = nx.degree_histogram(G)
fig, ax = plt.subplots()

sns.set_theme(style='whitegrid')
plt.yscale('log')
ax.hist(degree_freq);
ax.set_xlabel('Degree');
ax.set_ylabel('Frequency');
ax.set_title('Degree Distribution');

# %%
degree_freq = [x/sum(degree_freq) for x in degree_freq] #normalized degree frequency
degree_range = range(len(degree_freq)) 

fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Degree Distribution');
ax.set_xlabel('Degree');
ax.set_ylabel('Fraction of Nodes with Degree >= k');

deg = [0]*len(degree_freq)
sum_of_all = sum(degree_freq)
for i in range(len(deg)):
    for j in range(i,len(deg)):
        deg[i] += degree_freq[j]
    deg[i] = deg[i]/sum_of_all

ax.loglog(degree_range, deg);

if savefigs:
    plt.savefig('../figs/PowerLaw.png', bbox_inches = 'tight')

# %% [markdown]
# ### Graph representation

# %%
print(nx.is_directed(G))
print(nx.is_bipartite(G))
print(nx.is_weighted(G))
label= nx.get_node_attributes(G,'Label')
classification = nx.get_node_attributes(G,'0')
typeofclassification= nx.get_node_attributes(G,'1')

#classification[1329]
#typeofclassification[1329]

#G.nodes()
#nodes_attr
# Out:
# False
# True
# False

# %%
def draw_graph(G):   
    fig, ax = plt.subplots(figsize=(150,100))
    color_map = ['#7c0a02' if G.nodes[node]['bipartite'] == 0 else '#f4c2c2' for node in G]

    nx.draw(G, node_color = color_map, with_labels = True)

    plt.title('Graph representation', fontsize = 100);

# %% [markdown]
# # Visualizing the network using Pyvis

# %%
def make_interactive(attributes, edges):
    trial = attributes.set_index('Id')
    n = attributes['Id'].to_list()
    t= attributes['Label'].to_list()
    l= attributes['0'].to_list()
    l1 = attributes['1'].to_list()
    attributes['color'] = np.where(attributes['0']== 'disease', '#7c0a02' , '#f4c2c2')
    c = attributes['color'].to_list()


    net = Network('100vh', '100vw')

    net.add_nodes(n, title=l, label=t, color=c)
    net.add_edges(edges)
    net.show('jk.html')

# %%
#draw_graph(G)

# %%
Gp = bipartite.weighted_projected_graph(G, d_nodes)
#draw_graph(Gp)

# %%
t= pd.DataFrame(list(Gp.edges(data=True)), columns=['src', 'trg', 'Weight'])
#list(Gp.nodes(data=True))
t['Weight'] = [int(k['weight']) for k in t['Weight']]

t.to_csv(sep='\t', path_or_buf='../Data/new_file',header=True)

# %%
list(Gp.nodes(data=True))
# Out:
# [(55,
#   {'bipartite': 1,
#    'Label': 'Deafness',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ear,Nose,Throat',
#    'giantcomponent': 0}),
#  (47,
#   {'bipartite': 1,
#    'Label': 'Leukemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (114,
#   {'bipartite': 1,
#    'Label': 'Colon cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (45,
#   {'bipartite': 1,
#    'Label': 'Retinitis pigmentosa',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (87,
#   {'bipartite': 1,
#    'Label': 'Diabetes mellitus',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (54,
#   {'bipartite': 1,
#    'Label': 'Cardiomyopathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (81,
#   {'bipartite': 1,
#    'Label': 'Mental retardation',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (48,
#   {'bipartite': 1,
#    'Label': 'Blood group',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (70,
#   {'bipartite': 1,
#    'Label': 'Obesity',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Nutritional',
#    'giantcomponent': 0}),
#  (137,
#   {'bipartite': 1,
#    'Label': 'Breast cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (223,
#   {'bipartite': 1,
#    'Label': 'Muscular dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (390,
#   {'bipartite': 1,
#    'Label': 'Charcot-Marie-Tooth disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (220,
#   {'bipartite': 1,
#    'Label': 'Epilepsy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (325,
#   {'bipartite': 1,
#    'Label': 'Cataract',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (68,
#   {'bipartite': 1,
#    'Label': 'Asthma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Respiratory',
#    'giantcomponent': 0}),
#  (208,
#   {'bipartite': 1,
#    'Label': 'Complementary component deficiency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (213,
#   {'bipartite': 1,
#    'Label': 'Spinocereballar ataxia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (30,
#   {'bipartite': 1,
#    'Label': 'Alzheimer disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (65,
#   {'bipartite': 1,
#    'Label': 'Hypertension',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (139,
#   {'bipartite': 1,
#    'Label': 'Prostate cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (185,
#   {'bipartite': 1,
#    'Label': 'Leigh syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (202,
#   {'bipartite': 1,
#    'Label': 'Fanconi anemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (302,
#   {'bipartite': 1,
#    'Label': 'Epidermolysis bullosa',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (364,
#   {'bipartite': 1,
#    'Label': 'Parkinson disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (634,
#   {'bipartite': 1,
#    'Label': 'Thyroid carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (53,
#   {'bipartite': 1,
#    'Label': 'Myopathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (86,
#   {'bipartite': 1,
#    'Label': 'Hemolytic anemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (99,
#   {'bipartite': 1,
#    'Label': 'Myocardial infarction',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (117,
#   {'bipartite': 1,
#    'Label': 'Gastric cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (155,
#   {'bipartite': 1,
#    'Label': 'Lymphoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (41,
#   {'bipartite': 1,
#    'Label': 'Anemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (59,
#   {'bipartite': 1,
#    'Label': 'Pancreatic cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (130,
#   {'bipartite': 1,
#    'Label': 'Schizophrenia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Psychiatric',
#    'giantcomponent': 0}),
#  (239,
#   {'bipartite': 1,
#    'Label': 'Thrombophilia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (285,
#   {'bipartite': 1,
#    'Label': 'Ehlers-Danlos syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (640,
#   {'bipartite': 1,
#    'Label': 'Spastic ataxia/paraplegia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (63,
#   {'bipartite': 1,
#    'Label': 'Severe combined immunodeciency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (125,
#   {'bipartite': 1,
#    'Label': 'Hypercholesterolemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (197,
#   {'bipartite': 1,
#    'Label': 'Ovarian cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (224,
#   {'bipartite': 1,
#    'Label': 'Hepatic adenoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (236,
#   {'bipartite': 1,
#    'Label': 'Rheumatoid arthritis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (414,
#   {'bipartite': 1,
#    'Label': 'Ectodermal dysplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (420,
#   {'bipartite': 1,
#    'Label': 'Neuropathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (448,
#   {'bipartite': 1,
#    'Label': 'Factor x deficiency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (822,
#   {'bipartite': 1,
#    'Label': 'Usher syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (42,
#   {'bipartite': 1,
#    'Label': 'Cone dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (110,
#   {'bipartite': 1,
#    'Label': 'Long QT syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (122,
#   {'bipartite': 1,
#    'Label': 'Corneal dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (140,
#   {'bipartite': 1,
#    'Label': 'Spinal muscular atrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (146,
#   {'bipartite': 1,
#    'Label': 'Ichthyosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (186,
#   {'bipartite': 1,
#    'Label': 'Mitochondrial complex deciency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (266,
#   {'bipartite': 1,
#    'Label': 'Myasthenic syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (324,
#   {'bipartite': 1,
#    'Label': 'Leber congenital amaurosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (332,
#   {'bipartite': 1,
#    'Label': 'Hypothyroidism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (411,
#   {'bipartite': 1,
#    'Label': 'Hirschsprung disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Gastrointestinal',
#    'giantcomponent': 0}),
#  (775,
#   {'bipartite': 1,
#    'Label': 'Renal cell carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (37,
#   {'bipartite': 1,
#    'Label': 'Coronary artery disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (120,
#   {'bipartite': 1,
#    'Label': 'Amyloidosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (222,
#   {'bipartite': 1,
#    'Label': 'Osteoporosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (306,
#   {'bipartite': 1,
#    'Label': 'Epiphyseal dysplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (367,
#   {'bipartite': 1,
#    'Label': 'Amyotrophic lateral sclerosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (541,
#   {'bipartite': 1,
#    'Label': 'MODY',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (751,
#   {'bipartite': 1,
#    'Label': 'Dementia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (786,
#   {'bipartite': 1,
#    'Label': 'Pseudohypoaldosteronism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (44,
#   {'bipartite': 1,
#    'Label': 'Macular dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (74,
#   {'bipartite': 1,
#    'Label': 'Spondyloepiphyseal dysplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (109,
#   {'bipartite': 1,
#    'Label': 'Spherocytosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (164,
#   {'bipartite': 1,
#    'Label': 'Renal tubular acidosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Renal',
#    'giantcomponent': 0}),
#  (187,
#   {'bipartite': 1,
#    'Label': 'Central hypoventilation syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Respiratory',
#    'giantcomponent': 0}),
#  (200,
#   {'bipartite': 1,
#    'Label': 'Melanoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (215,
#   {'bipartite': 1,
#    'Label': 'Night blindness',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (219,
#   {'bipartite': 1,
#    'Label': 'Ataxia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (245,
#   {'bipartite': 1,
#    'Label': 'Malaria',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (327,
#   {'bipartite': 1,
#    'Label': 'Atrial fibrillation',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (384,
#   {'bipartite': 1,
#    'Label': 'Glioblastoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (607,
#   {'bipartite': 1,
#    'Label': 'Macular degeneration',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (661,
#   {'bipartite': 1,
#    'Label': 'Atopy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (736,
#   {'bipartite': 1,
#    'Label': 'Lipodystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (778,
#   {'bipartite': 1,
#    'Label': 'Bare lymphocyte syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (940,
#   {'bipartite': 1,
#    'Label': 'Holoprosencephaly',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Developmental',
#    'giantcomponent': 0}),
#  (80,
#   {'bipartite': 1,
#    'Label': 'Renal tubular dysgenesis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Renal',
#    'giantcomponent': 0}),
#  (119,
#   {'bipartite': 1,
#    'Label': 'Autoimmune disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (121,
#   {'bipartite': 1,
#    'Label': 'Apolipoprotein deficiency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (123,
#   {'bipartite': 1,
#    'Label': 'Hypertriglyceridemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (133,
#   {'bipartite': 1,
#    'Label': 'Systemic lupus erythematosus',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (158,
#   {'bipartite': 1,
#    'Label': 'Migraine',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (180,
#   {'bipartite': 1,
#    'Label': 'Maple syrup urine disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (199,
#   {'bipartite': 1,
#    'Label': 'Adenocarcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (203,
#   {'bipartite': 1,
#    'Label': 'Wilms tumor',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (235,
#   {'bipartite': 1,
#    'Label': 'Platelet defect/deficiency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (237,
#   {'bipartite': 1,
#    'Label': 'Myelogenous leukemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (248,
#   {'bipartite': 1,
#    'Label': 'Endometrial carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (277,
#   {'bipartite': 1,
#    'Label': 'Osteopetrosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (280,
#   {'bipartite': 1,
#    'Label': 'HIV',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (290,
#   {'bipartite': 1,
#    'Label': 'Osteoarthritis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (314,
#   {'bipartite': 1,
#    'Label': 'Lung cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (340,
#   {'bipartite': 1,
#    'Label': 'Glaucoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (369,
#   {'bipartite': 1,
#    'Label': 'Lissencephaly',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (401,
#   {'bipartite': 1,
#    'Label': 'Keratosis palmoplantaria striata',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (419,
#   {'bipartite': 1,
#    'Label': 'Dejerine-Sottas disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (423,
#   {'bipartite': 1,
#    'Label': 'Neutropenia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (429,
#   {'bipartite': 1,
#    'Label': 'Elliptocytosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (441,
#   {'bipartite': 1,
#    'Label': 'Anterior segment anomalies and cataract',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (447,
#   {'bipartite': 1,
#    'Label': 'Thrombocytopenia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (474,
#   {'bipartite': 1,
#    'Label': 'Bladder cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (497,
#   {'bipartite': 1,
#    'Label': 'Rhabdomyosarcoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (570,
#   {'bipartite': 1,
#    'Label': 'Autism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Psychiatric',
#    'giantcomponent': 0}),
#  (602,
#   {'bipartite': 1,
#    'Label': 'Huntington disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (782,
#   {'bipartite': 1,
#    'Label': 'Waardenburg syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (790,
#   {'bipartite': 1,
#    'Label': 'Meningioma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (851,
#   {'bipartite': 1,
#    'Label': 'Retinal cone dsytrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (938,
#   {'bipartite': 1,
#    'Label': 'Basal cell carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (968,
#   {'bipartite': 1,
#    'Label': 'Esophageal cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (43,
#   {'bipartite': 1,
#    'Label': 'Fundus albipunctatus',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (78,
#   {'bipartite': 1,
#    'Label': 'Tetralogy of Fallot',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (79,
#   {'bipartite': 1,
#    'Label': 'Preeclampsia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (101,
#   {'bipartite': 1,
#    'Label': 'Ichthyosiform erythroderma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (113,
#   {'bipartite': 1,
#    'Label': 'Adenomas',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (118,
#   {'bipartite': 1,
#    'Label': 'Turcot syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (132,
#   {'bipartite': 1,
#    'Label': 'Squamous cell carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (165,
#   {'bipartite': 1,
#    'Label': 'Cutis laxa',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (177,
#   {'bipartite': 1,
#    'Label': 'Hypercholanemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Gastrointestinal',
#    'giantcomponent': 0}),
#  (189,
#   {'bipartite': 1,
#    'Label': 'Obsessive-compulsive disorder',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Psychiatric',
#    'giantcomponent': 0}),
#  (201,
#   {'bipartite': 1,
#    'Label': 'Nonsmall cell lung cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (216,
#   {'bipartite': 1,
#    'Label': 'Hypokalemic periodic paralysis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Renal',
#    'giantcomponent': 0}),
#  (226,
#   {'bipartite': 1,
#    'Label': 'Ventricular tachycardia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (227,
#   {'bipartite': 1,
#    'Label': 'Hyperparathyroidism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (270,
#   {'bipartite': 1,
#    'Label': 'Nicotine addiction',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Psychiatric',
#    'giantcomponent': 0}),
#  (282,
#   {'bipartite': 1,
#    'Label': 'Achromatopsia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (292,
#   {'bipartite': 1,
#    'Label': 'Stickler syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (328,
#   {'bipartite': 1,
#    'Label': 'Atrioventricular block',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (402,
#   {'bipartite': 1,
#    'Label': 'Arrhythmogenic right ventricular dysplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (464,
#   {'bipartite': 1,
#    'Label': 'Walker-Warburg syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (467,
#   {'bipartite': 1,
#    'Label': 'Dysfibrinogenemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (527,
#   {'bipartite': 1,
#    'Label': 'Myoclonic epilepsy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (560,
#   {'bipartite': 1,
#    'Label': 'Erythrokeratoderma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (574,
#   {'bipartite': 1,
#    'Label': 'Pituitary ACTH-secreting adenoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (671,
#   {'bipartite': 1,
#    'Label': 'Myelodysplastic syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (703,
#   {'bipartite': 1,
#    'Label': 'Epidermolytic hyperkeratosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (742,
#   {'bipartite': 1,
#    'Label': 'Lipoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (744,
#   {'bipartite': 1,
#    'Label': 'Exudative vitreoretinopathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (795,
#   {'bipartite': 1,
#    'Label': 'Neurofibromatosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (796,
#   {'bipartite': 1,
#    'Label': 'Cleft palate',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Developmental',
#    'giantcomponent': 0}),
#  (856,
#   {'bipartite': 1,
#    'Label': 'Albinism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (880,
#   {'bipartite': 1,
#    'Label': 'Pyruvate dehydrogenase deciency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (919,
#   {'bipartite': 1,
#    'Label': 'Insulin resistance',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (953,
#   {'bipartite': 1,
#    'Label': 'Omenn syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (984,
#   {'bipartite': 1,
#    'Label': 'Paragangliomas',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (985,
#   {'bipartite': 1,
#    'Label': 'Pheochromocytoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (36,
#   {'bipartite': 1,
#    'Label': 'Cerebral amyloid angiopathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (38,
#   {'bipartite': 1,
#    'Label': 'HDL cholesterol level QTL',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (46,
#   {'bipartite': 1,
#    'Label': 'Stargardt disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (100,
#   {'bipartite': 1,
#    'Label': 'Stroke',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (126,
#   {'bipartite': 1,
#    'Label': 'Abetalipoproteinemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (128,
#   {'bipartite': 1,
#    'Label': 'Hyperlipoproteinemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (131,
#   {'bipartite': 1,
#    'Label': 'Urolithiasise',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (154,
#   {'bipartite': 1,
#    'Label': 'Ataxia-telangiectasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (156,
#   {'bipartite': 1,
#    'Label': 'T-cell lymphoblastic leukemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (181,
#   {'bipartite': 1,
#    'Label': 'von Hippel-Lindau syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (191,
#   {'bipartite': 1,
#    'Label': 'Cowden disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (192,
#   {'bipartite': 1,
#    'Label': 'Polyposis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (209,
#   {'bipartite': 1,
#    'Label': 'Combined immunodeficiency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (210,
#   {'bipartite': 1,
#    'Label': 'Cerebellar ataxia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (211,
#   {'bipartite': 1,
#    'Label': 'Episodic ataxia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (217,
#   {'bipartite': 1,
#    'Label': 'Malignant hyperthermia susceptibility',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (238,
#   {'bipartite': 1,
#    'Label': 'Homocystinuria',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (272,
#   {'bipartite': 1,
#    'Label': 'Myotonia congenita',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (286,
#   {'bipartite': 1,
#    'Label': 'Osteogenesis imperfecta',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (287,
#   {'bipartite': 1,
#    'Label': 'Marfan syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (307,
#   {'bipartite': 1,
#    'Label': 'Intervertebral disc disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (322,
#   {'bipartite': 1,
#    'Label': 'CPT deficiency, hepatic',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (323,
#   {'bipartite': 1,
#    'Label': 'Rubenstein-Taybi syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (331,
#   {'bipartite': 1,
#    'Label': 'Graves disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (341,
#   {'bipartite': 1,
#    'Label': 'Peters anomaly',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Developmental',
#    'giantcomponent': 0}),
#  (370,
#   {'bipartite': 1,
#    'Label': 'Subcortical laminar heterotopia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (385,
#   {'bipartite': 1,
#    'Label': 'Becker muscular dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (408,
#   {'bipartite': 1,
#    'Label': 'Atelosteogenesis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (417,
#   {'bipartite': 1,
#    'Label': 'Waardenburg-Shah syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (426,
#   {'bipartite': 1,
#    'Label': 'Emery-Dreifuss muscular dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (446,
#   {'bipartite': 1,
#    'Label': 'Hemorrhagic diathesis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (454,
#   {'bipartite': 1,
#    'Label': 'Ectopia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (457,
#   {'bipartite': 1,
#    'Label': 'Weill-Marchesani syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (463,
#   {'bipartite': 1,
#    'Label': 'Viral infection',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (466,
#   {'bipartite': 1,
#    'Label': 'Afibrinogenemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (470,
#   {'bipartite': 1,
#    'Label': 'Jackson-Weiss syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (471,
#   {'bipartite': 1,
#    'Label': 'Kallmann syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (472,
#   {'bipartite': 1,
#    'Label': 'Pfeiffer syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (476,
#   {'bipartite': 1,
#    'Label': 'Crouzon syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (483,
#   {'bipartite': 1,
#    'Label': 'Craniosynostosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (484,
#   {'bipartite': 1,
#    'Label': 'Saethre-Chotzen syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Developmental',
#    'giantcomponent': 0}),
#  (485,
#   {'bipartite': 1,
#    'Label': 'Cancer susceptibility',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (491,
#   {'bipartite': 1,
#    'Label': 'Iridogoniodysgenesis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (493,
#   {'bipartite': 1,
#    'Label': 'Rieger syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (526,
#   {'bipartite': 1,
#    'Label': 'Insomnia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Psychiatric',
#    'giantcomponent': 0}),
#  (545,
#   {'bipartite': 1,
#    'Label': 'Alexander disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (550,
#   {'bipartite': 1,
#    'Label': 'Growth hormone',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (559,
#   {'bipartite': 1,
#    'Label': 'Vohwinkel syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (575,
#   {'bipartite': 1,
#    'Label': 'Acromegaly',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (616,
#   {'bipartite': 1,
#    'Label': 'Creutzfeldt-Jakob disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (681,
#   {'bipartite': 1,
#    'Label': 'Polycythemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (682,
#   {'bipartite': 1,
#    'Label': 'Thrombocythemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (685,
#   {'bipartite': 1,
#    'Label': 'Jervell and Lange-Nielsen syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (691,
#   {'bipartite': 1,
#    'Label': 'Gastrointestinal stromal tumor',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (692,
#   {'bipartite': 1,
#    'Label': 'Germ cell tumor',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (765,
#   {'bipartite': 1,
#    'Label': 'Angelman syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Developmental',
#    'giantcomponent': 0}),
#  (767,
#   {'bipartite': 1,
#    'Label': 'Rett syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (772,
#   {'bipartite': 1,
#    'Label': 'Multiple endocrine neoplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (773,
#   {'bipartite': 1,
#    'Label': 'Parathyroid adenoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (779,
#   {'bipartite': 1,
#    'Label': 'Multiple sclerosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (784,
#   {'bipartite': 1,
#    'Label': 'Cafe-au-lait spots',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (785,
#   {'bipartite': 1,
#    'Label': 'Muir-Torre syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (793,
#   {'bipartite': 1,
#    'Label': 'Roussy-Levy syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (797,
#   {'bipartite': 1,
#    'Label': 'Hypodontia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (799,
#   {'bipartite': 1,
#    'Label': 'Parietal foramina',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (814,
#   {'bipartite': 1,
#    'Label': 'Central core disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (815,
#   {'bipartite': 1,
#    'Label': 'Carney complex',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (838,
#   {'bipartite': 1,
#    'Label': 'Neuroblastoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (853,
#   {'bipartite': 1,
#    'Label': 'Medullary thyroid carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (858,
#   {'bipartite': 1,
#    'Label': 'Optic atrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (873,
#   {'bipartite': 1,
#    'Label': 'Coloboma, ocular',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (930,
#   {'bipartite': 1,
#    'Label': 'Hyperprolinemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (963,
#   {'bipartite': 1,
#    'Label': 'Rh-negative blood type',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (982,
#   {'bipartite': 1,
#    'Label': 'Liddle syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Renal',
#    'giantcomponent': 0}),
#  (1048,
#   {'bipartite': 1,
#    'Label': 'Goiter',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (1050,
#   {'bipartite': 1,
#    'Label': 'Loeys-Dietz syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (1053,
#   {'bipartite': 1,
#    'Label': 'Thyroid hormone resistance',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (1061,
#   {'bipartite': 1,
#    'Label': 'Sepsis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (1067,
#   {'bipartite': 1,
#    'Label': 'Li-Fraumeni syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1070,
#   {'bipartite': 1,
#    'Label': 'Osteosarcoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1145,
#   {'bipartite': 1,
#    'Label': 'Medulloblastoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1245,
#   {'bipartite': 1,
#    'Label': 'Asperger syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Psychiatric',
#    'giantcomponent': 0}),
#  (39,
#   {'bipartite': 1,
#    'Label': 'Tangier disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (62,
#   {'bipartite': 1,
#    'Label': 'Adenosine deaminase deficiency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (69,
#   {'bipartite': 1,
#    'Label': 'Beta-2-adrenoreceptor agonist, reduced response to',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Unclassified',
#    'giantcomponent': 0}),
#  (76,
#   {'bipartite': 1,
#    'Label': 'Leanness, inherited',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Nutritional',
#    'giantcomponent': 0}),
#  (77,
#   {'bipartite': 1,
#    'Label': 'Alagille syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (98,
#   {'bipartite': 1,
#    'Label': 'Atherosclerosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (112,
#   {'bipartite': 1,
#    'Label': 'Adenoma, periampullary',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (115,
#   {'bipartite': 1,
#    'Label': 'Desmoid disease, hereditary',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (116,
#   {'bipartite': 1,
#    'Label': 'Gardner syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (124,
#   {'bipartite': 1,
#    'Label': 'Hypoalphalipoproteinemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (127,
#   {'bipartite': 1,
#    'Label': 'Hypobetalipoproteinemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (129,
#   {'bipartite': 1,
#    'Label': 'Sea-blue histiocyte disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (134,
#   {'bipartite': 1,
#    'Label': 'Aquaporin-1 deficiency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Unclassified',
#    'giantcomponent': 0}),
#  (136,
#   {'bipartite': 1,
#    'Label': 'Androgen insensitivity',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (138,
#   {'bipartite': 1,
#    'Label': 'Perineal hypospadias',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (147,
#   {'bipartite': 1,
#    'Label': 'Placental steroid sulfatase deciency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (157,
#   {'bipartite': 1,
#    'Label': 'Alternating hemiplegia of childhood',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (166,
#   {'bipartite': 1,
#    'Label': 'Menkes disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (167,
#   {'bipartite': 1,
#    'Label': 'Occipital horn syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (184,
#   {'bipartite': 1,
#    'Label': 'GRACILE syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (188,
#   {'bipartite': 1,
#    'Label': 'Memory impairment',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (198,
#   {'bipartite': 1,
#    'Label': 'Papillary serous carcinoma of the peritoneum',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (212,
#   {'bipartite': 1,
#    'Label': 'Hemiplegic migraine, familial',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (218,
#   {'bipartite': 1,
#    'Label': 'Thyrotoxic periodic paralysis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (225,
#   {'bipartite': 1,
#    'Label': 'Non-Hodgkin lymphoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (228,
#   {'bipartite': 1,
#    'Label': 'Hypocalcemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (229,
#   {'bipartite': 1,
#    'Label': 'Hypocalciuric hypercalcemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (231,
#   {'bipartite': 1,
#    'Label': 'Creatine phosphokinase',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (232,
#   {'bipartite': 1,
#    'Label': 'Rippling muscle disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (249,
#   {'bipartite': 1,
#    'Label': 'Listeria monocytogenes',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (252,
#   {'bipartite': 1,
#    'Label': 'Li Fraumeni syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (253,
#   {'bipartite': 1,
#    'Label': 'Orolaryngeal cancer',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (283,
#   {'bipartite': 1,
#    'Label': 'Caffey disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (284,
#   {'bipartite': 1,
#    'Label': 'Dissection of cervical arteries',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (288,
#   {'bipartite': 1,
#    'Label': 'Achondrogenesis-hypochondrogenesis, type II',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (289,
#   {'bipartite': 1,
#    'Label': 'Kniest dysplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (291,
#   {'bipartite': 1,
#    'Label': 'SMED Strudwick type',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (293,
#   {'bipartite': 1,
#    'Label': 'Wagner syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (294,
#   {'bipartite': 1,
#    'Label': 'Aneurysm, familial arterial',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Unclassified',
#    'giantcomponent': 0}),
#  (301,
#   {'bipartite': 1,
#    'Label': 'EBD',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (303,
#   {'bipartite': 1,
#    'Label': 'Toenail dystrophy, isolated',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (304,
#   {'bipartite': 1,
#    'Label': 'Transient bullous of the newborn',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (305,
#   {'bipartite': 1,
#    'Label': 'Fuchs endothelial corneal dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (310,
#   {'bipartite': 1,
#    'Label': 'Marshall syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (311,
#   {'bipartite': 1,
#    'Label': 'OSMED syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (312,
#   {'bipartite': 1,
#    'Label': 'Weissenbacher-Zweymuller syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (313,
#   {'bipartite': 1,
#    'Label': 'Pseudoachondroplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (316,
#   {'bipartite': 1,
#    'Label': 'Hemosiderosis, systemic, due to aceruloplasminemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (317,
#   {'bipartite': 1,
#    'Label': 'Hypoceruloplasminemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (334,
#   {'bipartite': 1,
#    'Label': 'Pilomatricoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (342,
#   {'bipartite': 1,
#    'Label': 'Coumarin resistance',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (363,
#   {'bipartite': 1,
#    'Label': 'Dopamine beta-hydroxylase deciency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (365,
#   {'bipartite': 1,
#    'Label': 'Angiotensin I-converting enzyme',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (366,
#   {'bipartite': 1,
#    'Label': 'SARS, progression of',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (368,
#   {'bipartite': 1,
#    'Label': 'Lower motor neuron disease, progressive, without sensory symptoms',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (374,
#   {'bipartite': 1,
#    'Label': 'Jensen syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (375,
#   {'bipartite': 1,
#    'Label': 'Mohr-Tranebjaerg syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (376,
#   {'bipartite': 1,
#    'Label': 'Meniere disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (380,
#   {'bipartite': 1,
#    'Label': 'Benzene toxicity',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Unclassified',
#    'giantcomponent': 0}),
#  (386,
#   {'bipartite': 1,
#    'Label': 'Duchenne muscular dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (403,
#   {'bipartite': 1,
#    'Label': 'Dilated cardiomyopathy with woolly hair and keratoderma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (404,
#   {'bipartite': 1,
#    'Label': 'Skin fragility-woolly hair syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (405,
#   {'bipartite': 1,
#    'Label': 'Dentin dysplasia, type II',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (406,
#   {'bipartite': 1,
#    'Label': 'Dentinogenesis imperfecta, Shields type',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (407,
#   {'bipartite': 1,
#    'Label': 'Achondrogenesis Ib',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (409,
#   {'bipartite': 1,
#    'Label': 'Diastrophic dysplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (415,
#   {'bipartite': 1,
#    'Label': 'Shah-Waardenburg syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (416,
#   {'bipartite': 1,
#    'Label': 'ABCD syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (422,
#   {'bipartite': 1,
#    'Label': 'Hematopoiesis, cyclic',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (424,
#   {'bipartite': 1,
#    'Label': 'Supravalvar aortic stenosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (425,
#   {'bipartite': 1,
#    'Label': 'Williams-Beuren syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (434,
#   {'bipartite': 1,
#    'Label': 'Estrogen resistance',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (442,
#   {'bipartite': 1,
#    'Label': 'Branchiootic syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (453,
#   {'bipartite': 1,
#    'Label': 'Aortic aneurysm',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (455,
#   {'bipartite': 1,
#    'Label': 'MASS syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (456,
#   {'bipartite': 1,
#    'Label': 'Shprintzen-Goldberg syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (468,
#   {'bipartite': 1,
#    'Label': 'Aarskog-Scott syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (473,
#   {'bipartite': 1,
#    'Label': 'Achondroplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (475,
#   {'bipartite': 1,
#    'Label': 'Cervical carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (477,
#   {'bipartite': 1,
#    'Label': 'Hypochondroplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (478,
#   {'bipartite': 1,
#    'Label': 'Muenke syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (479,
#   {'bipartite': 1,
#    'Label': 'Thanatophoric dysplasia, types I and II',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (480,
#   {'bipartite': 1,
#    'Label': 'Apert syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (481,
#   {'bipartite': 1,
#    'Label': 'Beare-Stevenson cutis gyrata syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (482,
#   {'bipartite': 1,
#    'Label': 'Craniofacial-skeletal-dermatologic dysplasia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (486,
#   {'bipartite': 1,
#    'Label': 'Hypofibrinogenemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (490,
#   {'bipartite': 1,
#    'Label': 'Axenfeld anomaly',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (492,
#   {'bipartite': 1,
#    'Label': 'Iris hypoplasia and glaucoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (502,
#   {'bipartite': 1,
#    'Label': 'Larson syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (503,
#   {'bipartite': 1,
#    'Label': 'Spondylocarpotarsal synostosis syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (523,
#   {'bipartite': 1,
#    'Label': 'Favism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (524,
#   {'bipartite': 1,
#    'Label': 'G6PD deficiency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (535,
#   {'bipartite': 1,
#    'Label': 'Dyserythropoietic anemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
# ...
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (887,
#   {'bipartite': 1,
#    'Label': 'Ossication of the posterior longitudinal spinal ligaments',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (888,
#   {'bipartite': 1,
#    'Label': 'Enlarged vestibular aqueduct',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ear,Nose,Throat',
#    'giantcomponent': 0}),
#  (889,
#   {'bipartite': 1,
#    'Label': 'Pendred syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ear,Nose,Throat',
#    'giantcomponent': 0}),
#  (897,
#   {'bipartite': 1,
#    'Label': 'Myoglobinuria/hemolysis due to PGK deciency',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (902,
#   {'bipartite': 1,
#    'Label': 'Emphysema',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Respiratory',
#    'giantcomponent': 0}),
#  (904,
#   {'bipartite': 1,
#    'Label': 'Ring dermoid of cornea',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (909,
#   {'bipartite': 1,
#    'Label': 'Nevo syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Connective tissue disorder',
#    'giantcomponent': 0}),
#  (911,
#   {'bipartite': 1,
#    'Label': 'Pelizaeus-Merzbacher disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (912,
#   {'bipartite': 1,
#    'Label': 'Neuroectodermal tumors',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (923,
#   {'bipartite': 1,
#    'Label': 'Adrenocortical carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (924,
#   {'bipartite': 1,
#    'Label': 'Myxoma, intracardiac',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (925,
#   {'bipartite': 1,
#    'Label': 'Pigmented adrenocortical disease, primary isolated',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (928,
#   {'bipartite': 1,
#    'Label': 'Gerstmann-Straussler disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (929,
#   {'bipartite': 1,
#    'Label': 'Prion disease with protracted course',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (935,
#   {'bipartite': 1,
#    'Label': 'Pick disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (939,
#   {'bipartite': 1,
#    'Label': 'Basal cell nevus syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (941,
#   {'bipartite': 1,
#    'Label': 'Bannayan-Riley-Ruvalcaba syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Unclassified',
#    'giantcomponent': 0}),
#  (942,
#   {'bipartite': 1,
#    'Label': 'Lhermitte-Duclos syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (943,
#   {'bipartite': 1,
#    'Label': 'Oligodendroglioma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (944,
#   {'bipartite': 1,
#    'Label': 'VATER association with hydrocephalus',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (947,
#   {'bipartite': 1,
#    'Label': 'Leopard syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (948,
#   {'bipartite': 1,
#    'Label': 'Noonan syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Developmental',
#    'giantcomponent': 0}),
#  (949,
#   {'bipartite': 1,
#    'Label': 'Zlotogora-Ogur syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (954,
#   {'bipartite': 1,
#    'Label': 'Capillary malformations',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (955,
#   {'bipartite': 1,
#    'Label': 'Parkes Weber syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (956,
#   {'bipartite': 1,
#    'Label': 'Retinoblastoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (958,
#   {'bipartite': 1,
#    'Label': 'Butterfly dystrophy, retinal',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (959,
#   {'bipartite': 1,
#    'Label': 'Foveomacular dystrophy, adult-onset, with choroidal neovascularization',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (960,
#   {'bipartite': 1,
#    'Label': 'Hyperproreninemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (961,
#   {'bipartite': 1,
#    'Label': 'Colonic aganglionosis, total, with small bowel involvement',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Gastrointestinal',
#    'giantcomponent': 0}),
#  (962,
#   {'bipartite': 1,
#    'Label': 'Rh-mod syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (965,
#   {'bipartite': 1,
#    'Label': 'Bothnia retinal dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (966,
#   {'bipartite': 1,
#    'Label': 'Newfoundland rod-cone dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (969,
#   {'bipartite': 1,
#    'Label': 'Coffin-Lowry syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (974,
#   {'bipartite': 1,
#    'Label': 'Cramps, potassium-aggravated',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (975,
#   {'bipartite': 1,
#    'Label': 'Hyperkalemic periodic paralysis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (976,
#   {'bipartite': 1,
#    'Label': 'Paramyotonia congenita',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (977,
#   {'bipartite': 1,
#    'Label': 'Brugada syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (978,
#   {'bipartite': 1,
#    'Label': 'Heart block',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (979,
#   {'bipartite': 1,
#    'Label': 'Sick sinus syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (980,
#   {'bipartite': 1,
#    'Label': 'Ventricular brillation, idiopathic',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (986,
#   {'bipartite': 1,
#    'Label': 'Carcinoid tumors, intestinal',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (987,
#   {'bipartite': 1,
#    'Label': 'Merkel cell carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (991,
#   {'bipartite': 1,
#    'Label': 'Solitary median maxillary central incisor',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Skeletal',
#    'giantcomponent': 0}),
#  (996,
#   {'bipartite': 1,
#    'Label': 'Fanconi-Bickel syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (1002,
#   {'bipartite': 1,
#    'Label': 'Anxiety-related personality traits',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Psychiatric',
#    'giantcomponent': 0}),
#  (1003,
#   {'bipartite': 1,
#    'Label': 'Creatine deciency syndrome, X-linked',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (1012,
#   {'bipartite': 1,
#    'Label': 'Infundibular hypoplasia and hypopituitarism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (1015,
#   {'bipartite': 1,
#    'Label': 'PCWH',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (1016,
#   {'bipartite': 1,
#    'Label': 'Yemenite deaf-blind hypopigmentation syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (1020,
#   {'bipartite': 1,
#    'Label': 'Pyropoikilocytosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (1025,
#   {'bipartite': 1,
#    'Label': 'Peutz-Jeghers syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1027,
#   {'bipartite': 1,
#    'Label': 'Hypoglycemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (1029,
#   {'bipartite': 1,
#    'Label': 'Wegener granulomatosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (1033,
#   {'bipartite': 1,
#    'Label': 'Barth syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (1034,
#   {'bipartite': 1,
#    'Label': 'Noncompaction of left ventricular myocardium',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (1040,
#   {'bipartite': 1,
#    'Label': 'Glomerulocystic kidney disease, hypoplastic',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Renal',
#    'giantcomponent': 0}),
#  (1047,
#   {'bipartite': 1,
#    'Label': 'Autoimmune thyroid disease',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (1051,
#   {'bipartite': 1,
#    'Label': 'Self-healing collodion baby',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (1065,
#   {'bipartite': 1,
#    'Label': 'Adrenal cortical carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1066,
#   {'bipartite': 1,
#    'Label': 'Histiocytoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1068,
#   {'bipartite': 1,
#    'Label': 'Multiple malignancy syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1069,
#   {'bipartite': 1,
#    'Label': 'Nasopharyngeal carcinoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1072,
#   {'bipartite': 1,
#    'Label': 'Hyperthyroidism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (1073,
#   {'bipartite': 1,
#    'Label': 'Total iodide organication defect',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (1078,
#   {'bipartite': 1,
#    'Label': 'Hyperthroidism',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Endocrine',
#    'giantcomponent': 0}),
#  (1080,
#   {'bipartite': 1,
#    'Label': 'Amyloid neuropathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (1081,
#   {'bipartite': 1,
#    'Label': 'Carpal tunnel syndrome, familial',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Unclassified',
#    'giantcomponent': 0}),
#  (1082,
#   {'bipartite': 1,
#    'Label': 'Dystransthyretinemic hyperthyroxinemia',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Hematological',
#    'giantcomponent': 0}),
#  (1089,
#   {'bipartite': 1,
#    'Label': 'Hemangioblastoma, cerebellar',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1091,
#   {'bipartite': 1,
#    'Label': "Maculopathy, bull's-eye",
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (1092,
#   {'bipartite': 1,
#    'Label': 'Vitelliform macular dystrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (1094,
#   {'bipartite': 1,
#    'Label': 'Wiskott-Aldrich syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (1099,
#   {'bipartite': 1,
#    'Label': 'Denys-Drash syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Renal',
#    'giantcomponent': 0}),
#  (1100,
#   {'bipartite': 1,
#    'Label': 'Frasier syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (1101,
#   {'bipartite': 1,
#    'Label': 'Mesangial sclerosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Renal',
#    'giantcomponent': 0}),
#  (1102,
#   {'bipartite': 1,
#    'Label': 'WAGR syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (1120,
#   {'bipartite': 1,
#    'Label': 'Salivary adenoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1121,
#   {'bipartite': 1,
#    'Label': 'Uterine leiomyoma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1130,
#   {'bipartite': 1,
#    'Label': 'Miyoshi myopathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (1132,
#   {'bipartite': 1,
#    'Label': 'Oligodontia-colorectal cancer syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1136,
#   {'bipartite': 1,
#    'Label': 'Incontinentia pigmenti',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (1148,
#   {'bipartite': 1,
#    'Label': 'Arthropathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Bone',
#    'giantcomponent': 0}),
#  (1152,
#   {'bipartite': 1,
#    'Label': 'Mesothelioma',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1153,
#   {'bipartite': 1,
#    'Label': 'Sezary syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cancer',
#    'giantcomponent': 0}),
#  (1174,
#   {'bipartite': 1,
#    'Label': 'Myotilinopathy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Muscular',
#    'giantcomponent': 0}),
#  (1181,
#   {'bipartite': 1,
#    'Label': 'Enhanced S-cone syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (1198,
#   {'bipartite': 1,
#    'Label': 'Netherton syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (1208,
#   {'bipartite': 1,
#    'Label': 'Pigmented paravenous chorioretinal atrophy',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (1221,
#   {'bipartite': 1,
#    'Label': 'Silver spastic paraplegia syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (1227,
#   {'bipartite': 1,
#    'Label': 'Craniofacial anomalies, empty sella turcica, corneal endothelial changes',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (1228,
#   {'bipartite': 1,
#    'Label': 'Keratoconus',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Ophthamological',
#    'giantcomponent': 0}),
#  (1232,
#   {'bipartite': 1,
#    'Label': 'Immunodysregulation, polyendocrinopathy, and enteropathy, X-linked',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (1238,
#   {'bipartite': 1,
#    'Label': 'IgE levels QTL',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Immunological',
#    'giantcomponent': 0}),
#  (1242,
#   {'bipartite': 1,
#    'Label': 'Wolff-Parkinson-White syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Cardiovascular',
#    'giantcomponent': 0}),
#  (1270,
#   {'bipartite': 1,
#    'Label': 'Primary lateral sclerosis',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (1285,
#   {'bipartite': 1,
#    'Label': '3-methylglutaconicaciduria',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Metabolic',
#    'giantcomponent': 0}),
#  (1289,
#   {'bipartite': 1,
#    'Label': 'Convulsions',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (1303,
#   {'bipartite': 1,
#    'Label': 'Infantile spasm syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (1304,
#   {'bipartite': 1,
#    'Label': 'Partington syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Neurological',
#    'giantcomponent': 0}),
#  (1305,
#   {'bipartite': 1,
#    'Label': 'Proud syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Multiple',
#    'giantcomponent': 0}),
#  (1306,
#   {'bipartite': 1,
#    'Label': 'Birt-Hogg-Dube syndrome',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Dermatological',
#    'giantcomponent': 0}),
#  (1307,
#   {'bipartite': 1,
#    'Label': 'Pneumothorax, primary spontaneous',
#    'timeset': nan,
#    '0': 'disease',
#    '1': 'Respiratory',
#    'giantcomponent': 0})]

# %%
def visualize_bipar():
    temp = d_attributes
    categories = np.unique(d_attributes['1'])
    temp['1'] = pd.Categorical(temp['1'])

    pos = nx.spring_layout(Gp)
    colorlegend = {a:b  for b,a in enumerate(categories)}

    colours = ['#800000', '#FF0000', '#FF7F50', '#FF8C00', '#FFD700',
    '#EEE8AA', '#BDB76B', '#808000', '#7CFC00', '#006400', 
    '#98FB98', '#20B2AA', '#2F4F4F', '#00FFFF', '#AFEEEE',
    '#6495ED','#191970','#8A2BE2','#4B0082','#DDA0DD',
    '#A0522D','#DEB887']
    colours = ListedColormap(colours)

    val_map = temp['1'].cat.codes.to_dict()
    values = [val_map.get(node, 0) for node in Gp.nodes()]
    cNorm  = colors.Normalize(vmin=0, vmax=max(values))
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=colours)

    f = plt.figure(1, figsize=(30, 20))
    ax = f.add_subplot(1,1,1)
    for label in colorlegend:
        ax.plot([0],[0],color=scalarMap.to_rgba(colorlegend[label]),label=label)

    nx.draw(Gp, pos,  node_color = temp['1'].cat.codes, cmap = colours, vmin = 0, vmax = max(values))

    plt.legend();

    if savefigs:
        plt.savefig('../figs/BiparNetwork.png', bbox_inches = 'tight')

visualize_bipar()

# %% [markdown]
# ## Assortativity of the projected network
# We use the function $trace(M)-sum(M^2))/(1-sum(M^2))$, where M is the joint probability distribution (mixing matrix) of the specified attribute.
# or in easier to understand math
# $$r = \dfrac{\sum_ie_{ii} - \sum_ia_ib_i}{1-\sum_ia_ib_i}$$

# %%
nx.attribute_assortativity_coefficient(Gp, "1")
# Out:
# 0.4412095585382885

# %% [markdown]
# A score of 0.44 means we can say it is moderately assortative since it is above 0 on a [-1;1] scale.

# %% [markdown]
# ## Clustering

# %%
#global clustering coefficient
print(nx.transitivity(Gp))

#average clustering coefficient
print(nx.average_clustering(Gp))

#local clustering coefficient
print(nx.clustering(Gp))
# Out:
# 0.4304705634100021
# 0.6358304997771198
# {55: 0.08, 47: 0.1076923076923077, 114: 0.12408163265306123, 45: 0.125, 87: 0.09057971014492754, 54: 0.10476190476190476, 81: 0.18681318681318682, 48: 0.21428571428571427, 70: 0.2857142857142857, 137: 0.22298850574712645, 223: 0.25, 390: 0.3, 220: 0, 325: 0.6545454545454545, 68: 0.16363636363636364, 208: 0, 213: 0.4, 30: 0.19047619047619047, 65: 0.19444444444444445, 139: 0.2789473684210526, 185: 0.13333333333333333, 202: 1.0, 302: 0.25, 364: 0.13333333333333333, 634: 0.27692307692307694, 53: 0.25, 86: 0.25, 99: 0.28888888888888886, 117: 0.19658119658119658, 155: 0.37362637362637363, 41: 0.3333333333333333, 59: 0.2924901185770751, 130: 0.3333333333333333, 239: 0.14285714285714285, 285: 0.38095238095238093, 640: 0.3333333333333333, 63: 0, 125: 0.3333333333333333, 197: 0.35, 224: 0.425, 236: 0.14285714285714285, 414: 0.16666666666666666, 420: 1.0, 448: 0.5, 822: 0, 42: 0.5333333333333333, 110: 0.3333333333333333, 122: 0.3333333333333333, 140: 0.19444444444444445, 146: 0.2857142857142857, 186: 0.6666666666666666, 266: 1.0, 324: 0.6666666666666666, 332: 0.2, 411: 0.25, 775: 0.39285714285714285, 37: 1.0, 120: 0.2, 222: 0.3484848484848485, 306: 0.19047619047619047, 367: 0.16666666666666666, 541: 0.26666666666666666, 751: 0.2222222222222222, 786: 0, 44: 0.35714285714285715, 74: 0.3333333333333333, 109: 0.5333333333333333, 164: 1.0, 187: 0.32142857142857145, 200: 0.35714285714285715, 215: 0, 219: 0, 245: 0.4666666666666667, 327: 0.2, 384: 0.3516483516483517, 607: 0.19047619047619047, 661: 0.3333333333333333, 736: 0.2857142857142857, 778: 0.3333333333333333, 940: 0.3333333333333333, 80: 0.4642857142857143, 119: 0.16666666666666666, 121: 0.6, 123: 0.6, 133: 1.0, 158: 0.3333333333333333, 180: 0, 199: 0.39285714285714285, 203: 0.3333333333333333, 235: 0.3, 237: 1.0, 248: 0.4725274725274725, 277: 1.0, 280: 1.0, 290: 0.5238095238095238, 314: 0.7333333333333333, 340: 0, 369: 0.6666666666666666, 401: 0.42857142857142855, 419: 1.0, 423: 0.16666666666666666, 429: 0.5333333333333333, 441: 0.4, 447: 0.3333333333333333, 474: 0.3619047619047619, 497: 0.3333333333333333, 570: 0.7, 602: 0.4666666666666667, 782: 0.16666666666666666, 790: 0.45454545454545453, 851: 0, 938: 0.2, 968: 1.0, 43: 0.6, 78: 0.3333333333333333, 79: 0.3333333333333333, 101: 1.0, 113: 1.0, 118: 0.5277777777777778, 132: 0, 165: 0.2, 177: 0, 189: 0.3333333333333333, 201: 0.5238095238095238, 216: 0.5238095238095238, 226: 0, 227: 0.6111111111111112, 270: 0, 282: 0, 292: 0.3611111111111111, 328: 0.4, 402: 0.6, 464: 0, 467: 0.5, 527: 0.6666666666666666, 560: 1.0, 574: 0.6666666666666666, 671: 1.0, 703: 0.7, 742: 0.4888888888888889, 744: 0.5714285714285714, 795: 0.3717948717948718, 796: 0.3333333333333333, 856: 0, 880: 0, 919: 1.0, 953: 0, 984: 1.0, 985: 0.42857142857142855, 36: 1.0, 38: 0.4, 46: 1.0, 100: 0, 126: 1.0, 128: 1.0, 131: 0, 154: 1.0, 156: 0.8333333333333334, 181: 0.5333333333333333, 191: 0.7777777777777778, 192: 0.3333333333333333, 209: 0, 210: 0.4, 211: 1.0, 217: 0.3333333333333333, 238: 0, 272: 1.0, 286: 0.8, 287: 0.4642857142857143, 307: 0, 322: 0, 323: 0, 331: 0, 341: 0.8, 370: 0, 385: 0.6666666666666666, 408: 0.4, 417: 0.3333333333333333, 426: 1.0, 446: 0.3333333333333333, 454: 0.5054945054945055, 457: 1.0, 463: 0, 466: 0.6666666666666666, 470: 0.8055555555555556, 471: 1.0, 472: 0.8055555555555556, 476: 0.47619047619047616, 483: 0.7777777777777778, 484: 1.0, 485: 1.0, 491: 0.7, 493: 0.7, 526: 1.0, 545: 1.0, 550: 0, 559: 0.7333333333333333, 575: 1.0, 616: 1.0, 681: 0.4666666666666667, 682: 1.0, 685: 1.0, 691: 0.6666666666666666, 692: 0.4722222222222222, 765: 1.0, 767: 1.0, 772: 0.4909090909090909, 773: 1.0, 779: 0.3333333333333333, 784: 0.8214285714285714, 785: 0.8214285714285714, 793: 1.0, 797: 0.3333333333333333, 799: 0, 814: 0.3333333333333333, 815: 0.6, 838: 1.0, 853: 0.6, 858: 0, 873: 0.6727272727272727, 930: 0, 963: 0, 982: 0, 1048: 0.4, 1050: 1.0, 1053: 1.0, 1061: 1.0, 1067: 0.8909090909090909, 1070: 0.8909090909090909, 1145: 0, 1245: 1.0, 39: 1.0, 62: 0, 69: 1.0, ...

# %%
from collections import defaultdict

def homophily_per_group(graph):
    types_diseases = defaultdict(list)
    for node in graph.nodes():
        group = graph.nodes[node]['1']
        count = 0 
        num_neighbors= len(list(graph.neighbors(node)))
        for n_node in list(graph.neighbors(node)):
            n_group= graph.nodes[n_node]['1']
            
            if group == n_group: 
                count +=1
                
        types_diseases[group].append(count/num_neighbors)
   
    for key,val in types_diseases.items():
        value = np.round(sum(val) / len(val), decimals=3)
        types_diseases.update({key: [value]})
        
    df = pd.DataFrame.from_dict(types_diseases, orient='columns')
    return df 


#homophily_per_group(bipar_weighted).items()



def list_degrees(graph): 
    l = list(graph.degree())
    l_sorted= sorted(l, key=lambda t: t[1], reverse=True)
    
    return l_sorted

degrees = pd.DataFrame(list_degrees(Gp), columns=['NodeID', 'Degree'])

plt.figure(1, figsize=(15, 15))
sns.histplot(data=degrees,  x='Degree')
plt.title('Degree Distribution', fontsize=50)
plt.xlabel('Nodes', size=20)
plt.ylabel('Degrees', size=20)

if savefigs:
    plt.savefig('../figs/DegreeBipartite.png', bbox_inches = 'tight')

# %%
degrees.head(200)
Gp.nodes[45]['1']
homophily_per_group(Gp)
list(Gp.neighbors(68))
def group(graph):
    dict_nodes=defaultdict(list)
    num_nodes = defaultdict(int)
    for node in graph.nodes():
        group = graph.nodes[node]['1']
        dict_nodes[group].append(node)
        num_nodes[group] += 1
    
    return dict_nodes, num_diseases


group(Gp)

#barplot of nodes above th
#th at least 5% of the data -> 26
#68, 187, 902, 1307

Gp.nodes[1307]
# Out:
# {'bipartite': 1,
#  'Label': 'Pneumothorax, primary spontaneous',
#  'timeset': nan,
#  '0': 'disease',
#  '1': 'Respiratory',
#  'giantcomponent': 0}

# %%
from networkx.algorithms.community import greedy_modularity_communities
homophily_per_group(Gp)
# Out:
#    Ear,Nose,Throat  Cancer  Ophthamological  Endocrine  Cardiovascular  \
# 0            0.693   0.794            0.768      0.505           0.462
#
#    Neurological  Hematological  Nutritional  Muscular  Respiratory  ...  \
# 0         0.537          0.563        0.375     0.497          0.0  ...
#
#    Dermatological  Psychiatric  Connective tissue disorder  Metabolic  \
# 0           0.616        0.364                        0.25        0.2
#
#    Gastrointestinal   Bone  Skeletal  Renal  Developmental  Unclassified
# 0              0.09  0.317     0.359  0.062          0.094           0.0
#
# [1 rows x 22 columns]

# %%
from scipy.stats.contingency import crosstab
from sklearn.metrics import mutual_info_score
from sklearn.metrics import normalized_mutual_info_score
c = greedy_modularity_communities(Gp, n_communities=22)

expected = pd.DataFrame(Gp.nodes())
expected["color"]= 0
expected.columns = ["node", "group_num"]
expected['nodes']= Gp.nodes()

exp = expected.set_index("node")

for i, lst in enumerate(c):
    for nod in list(lst):
        exp.loc[nod]['group_num'] = i

groups= []
for node in exp['nodes']:
    groups.append(Gp.nodes[node]['1'])
exp['group']= groups 
normalized_mutual_info_score(exp['group_num'], exp['group'])
# Out:
# 0.4401933593741316

# %%
genes = pd.DataFrame(columns=['gene','weight'])
genes['gene']=g_nodes

genes_df= genes.set_index('gene')
for gene in g_nodes:
    lst= list(G.neighbors(gene))
    total_weight = 0
    for i in lst:
        weight = 1/len(list(G.neighbors(i)))
        total_weight += weight
    genes_df.at[gene,'weight']= total_weight/G.degree(gene)
genes_df.reset_index()
genes_df.sort_index(key=lambda x: genes_df['weight'], ascending=False, inplace=True)

genes_df
# Out:
#         weight
# gene
# 3854      0.85
# 3653  0.833333
# 3875  0.833333
# 2569  0.833333
# 3913  0.833333
# ...        ...
# 1990   0.02439
# 1992   0.02439
# 1994   0.02439
# 1996   0.02439
# 2008   0.02439
#
# [903 rows x 1 columns]

# %%
for node_desease in list(G.neighbors(3720)):
    print(Gp.nodes[node_desease]['1'])
# Out:
# Skeletal
# Cancer
# Cancer
# Cancer
# Skeletal
# Skeletal
# Skeletal
# Skeletal

# %%
expected = pd.DataFrame(Gp.nodes())
expected["color"]= 0
expected.columns = ["node", "group_num"]
expected['nodes']= Gp.nodes()

exp = expected.set_index("node")
print(exp)
exp['group']= "none" 
for i, lst in enumerate(c):
    for nod in list(lst):
        exp.loc[nod]['group_num'] = i

for node in exp['nodes']:
    exp.loc[node]['group']= Gp.nodes[node]['1']

normalized_mutual_info_score(exp['group_num'], exp['group'])

exp.loc[55]['group'] = "casa"
exp.loc[55]['group']
# Out:
#       group_num  nodes
# node
# 55            0     55
# 47            0     47
# 114           0    114
# 45            0     45
# 87            0     87
# ...         ...    ...
# 1303          0   1303
# 1304          0   1304
# 1305          0   1305
# 1306          0   1306
# 1307          0   1307
#
# [516 rows x 2 columns]
# 'none'

# %% [markdown]
# ### Targeted Attacks

# %% [markdown]
# We first make a sorted list in descending order

# %%
sorted_G_nodes = list_degrees(G)
gcc_sizes = []

# %%
L = G.copy()
for i in range(20):
   gcc_sizes.append(len(max(nx.connected_components(L), key = len)) / len(G.nodes))
   L.remove_node(sorted_G_nodes[i][0])

# %%
K = G.copy()
sizes = list(genes_df.iterrows())
size_weighted = []

for gene in sizes:
    size_weighted.append(len(max(nx.connected_components(K), key = len)) / len(G.nodes))
    K.remove_node(gene[0])

# %%
size_weighted = size_weighted[:20]
print(size_weighted)
# Out:
# [1.0, 0.9964763918252291, 0.9943622269203665, 0.9922480620155039, 0.9901338971106413, 0.9873150105708245, 0.9837914023960536, 0.9788583509513742, 0.9753347427766033, 0.9725158562367865, 0.9696969696969697, 0.9675828047921071, 0.9654686398872445, 0.9633544749823819, 0.9612403100775194, 0.9591261451726568, 0.95630725863284, 0.937984496124031, 0.8865398167723749, 0.883016208597604]

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ### Combining targeted attacks and community discovery
#
# We made a class ```ClassAnalysis()``` in the file main.py where we combine the idea of targeted attacks with community discovery algorithms. Our results are visualized in the following plots:

# %%
# list of genes sorted by their degree
l_sorted = [(gene, G.degree[gene])for gene in g_nodes]
l_sorted = sorted(l_sorted, key=lambda t: t[1], reverse=True)
l_sorted = [x[0] for x in l_sorted]

# %%
def random_sample(num):
    sample = np.random.choice(g_nodes, num)
    return sample

# %%
nodes_weight = [i[0] for i in sizes]
nodes_weight = nodes_weight[:20]

analysis_d = GraphAnalysis(G.copy(), l_sorted[:20], d_nodes)
analysis_w = GraphAnalysis(G.copy(), nodes_weight, d_nodes)
analysis_r = GraphAnalysis(G.copy(), random_sample(20), d_nodes)
df_homophily_d, df_community_d, largest_component_d = analysis_d.final_analysis()
df_homophily_w, df_community_w, largest_component_w = analysis_w.final_analysis()
df_homophily_r, df_community_r, largest_component_r = analysis_r.final_analysis()

# %%
df_homophily_d
# Out:
#     Ear,Nose,Throat    Cancer  Ophthamological  Endocrine  Cardiovascular  \
# 0               2.0  5.113636         3.743590   1.777778        1.703704
# 1               2.0  5.113636         2.307692   1.777778        1.703704
# 2               2.0  5.113636         2.307692   1.777778        1.703704
# 3               2.0  4.636364         2.307692   1.777778        1.703704
# 4               2.0  4.136364         2.307692   1.777778        1.703704
# 5               2.0  4.068182         2.307692   1.777778        1.703704
# 6               2.0  3.840909         2.307692   1.555556        1.703704
# 7               2.0  3.454545         2.307692   1.555556        1.703704
# 8               2.0  3.454545         2.307692   1.555556        1.703704
# 9               2.0  3.454545         2.307692   1.555556        1.703704
# 10              2.0  3.318182         2.307692   1.555556        1.703704
# 11              2.0  3.318182         2.307692   1.555556        1.703704
# 12              2.0  3.318182         2.307692   1.333333        1.703704
# 13              2.0  3.022727         2.307692   1.333333        1.703704
# 14              2.0  3.022727         2.307692   1.333333        1.703704
# 15              2.0  3.022727         2.307692   1.333333        1.703704
# 16              2.0  3.022727         2.307692   1.333333        1.703704
# 17              2.0  3.022727         2.307692   1.259259        1.703704
# 18              2.0  3.022727         2.307692   1.259259        1.703704
# 19              2.0  2.954545         2.307692   1.259259        1.703704
#
#     Neurological  Hematological  Nutritional  Muscular  Respiratory  ...  \
# 0       1.963636       1.823529     0.666667       2.0          0.0  ...
# 1       1.963636       1.823529     0.666667       2.0          0.0  ...
# 2       1.963636       1.823529     0.666667       2.0          0.0  ...
# 3       1.963636       1.823529     0.666667       2.0          0.0  ...
# 4       1.963636       1.823529     0.666667       2.0          0.0  ...
# 5       1.963636       1.823529     0.666667       2.0          0.0  ...
# 6       1.963636       1.823529     0.666667       2.0          0.0  ...
# 7       1.963636       1.823529     0.666667       2.0          0.0  ...
# 8       1.963636       1.823529     0.666667       2.0          0.0  ...
# 9       1.963636       1.823529     0.666667       1.2          0.0  ...
# 10      1.963636       1.823529     0.666667       1.2          0.0  ...
# 11      1.600000       1.823529     0.666667       1.2          0.0  ...
# 12      1.600000       1.823529     0.666667       1.2          0.0  ...
# 13      1.600000       1.823529     0.666667       1.2          0.0  ...
# 14      1.600000       1.823529     0.666667       1.2          0.0  ...
# 15      1.600000       1.823529     0.666667       1.2          0.0  ...
# 16      1.600000       1.823529     0.666667       1.2          0.0  ...
# 17      1.600000       1.823529     0.666667       1.2          0.0  ...
# 18      1.600000       1.823529     0.666667       1.2          0.0  ...
# 19      1.600000       1.823529     0.666667       1.2          0.0  ...
#
#     Dermatological  Psychiatric  Connective tissue disorder  Metabolic  \
# 0         2.380952         1.25                    1.066667     0.6250
# 1         2.380952         1.25                    1.066667     0.6250
# 2         2.380952         1.25                    1.066667     0.6250
# 3         2.380952         1.25                    1.066667     0.6250
# 4         2.380952         1.25                    1.066667     0.6250
# 5         2.380952         1.25                    1.066667     0.6250
# 6         2.380952         1.25                    1.066667     0.6250
# 7         2.380952         1.25                    1.066667     0.6250
# 8         2.380952         1.25                    1.066667     0.6250
# 9         2.380952         1.25                    1.066667     0.6250
# 10        2.380952         1.25                    1.066667     0.6250
# 11        2.380952         1.25                    1.066667     0.6250
# 12        2.380952         1.25                    1.066667     0.6250
# 13        2.380952         1.25                    1.066667     0.6250
# 14        2.380952         1.25                    1.066667     0.6250
# 15        2.380952         1.25                    1.066667     0.6250
# 16        2.380952         1.25                    0.666667     0.6250
# 17        2.380952         1.25                    0.666667     0.6250
# 18        2.380952         1.25                    0.666667     0.4375
# 19        2.380952         1.25                    0.666667     0.4375
#
#     Gastrointestinal      Bone  Skeletal  Renal  Developmental  Unclassified
# 0                0.5  1.733333  1.826087   0.25           0.25           0.0
# 1                0.5  1.733333  1.826087   0.25           0.25           0.0
# 2                0.5  1.733333  1.391304   0.25           0.25           0.0
# 3                0.5  1.733333  1.391304   0.25           0.25           0.0
# 4                0.5  1.733333  1.391304   0.25           0.25           0.0
# 5                0.5  1.733333  0.521739   0.25           0.25           0.0
# 6                0.5  1.733333  0.521739   0.25           0.25           0.0
# 7                0.5  1.733333  0.521739   0.25           0.25           0.0
# 8                0.5  0.400000  0.521739   0.25           0.25           0.0
# 9                0.5  0.400000  0.521739   0.25           0.25           0.0
# 10               0.5  0.400000  0.521739   0.25           0.25           0.0
# 11               0.5  0.400000  0.521739   0.25           0.25           0.0
# 12               0.5  0.400000  0.521739   0.25           0.25           0.0
# 13               0.5  0.400000  0.521739   0.25           0.25           0.0
# 14               0.5  0.400000  0.521739   0.25           0.25           0.0
# 15               0.5  0.400000  0.434783   0.25           0.25           0.0
# 16               0.5  0.400000  0.434783   0.25           0.25           0.0
# 17               0.5  0.400000  0.434783   0.25           0.25           0.0
# 18               0.5  0.400000  0.434783   0.25           0.25           0.0
# 19               0.5  0.400000  0.434783   0.25           0.25           0.0
#
# [20 rows x 22 columns]

# %% [markdown]
# ### Visualizations of our results

# %%
# add a 1 to the beginning of the list of the connected components
largest_component_d.insert(0, 1)
largest_component_r.insert(0, 1)
largest_component_w.insert(0, 1)

# %%
fig, ax = plt.subplots(figsize = (8,6))
plot_data = pd.DataFrame({
    'NumNodes' : [i for i in range(21)],
    'Degree' : largest_component_d,
    'Weighted Degree': largest_component_w,
    'Random': largest_component_r
})
colors_taratt = ['#761878', '#826fc9', '#b1c2f0']
sns.lineplot(x = 'NumNodes', y = 'value', hue = 'Targeting by', palette = colors_taratt, data = pd.melt(plot_data, ['NumNodes'], var_name= 'Targeting by'));
plt.suptitle('Probability of being in the largest component', size = 15, weight ='bold')
ax.set_title('using targeted attacks', size = 13)
ax.set(xlabel = 'Number of deleted nodes', ylabel= 'Probability of being in the largest component');

if savefigs:
    plt.savefig('../figs/LargestComponents.png', bbox_inches = 'tight')

# %%
df_community_w
# Out:
#          nmi  modularity
# 0   0.441242    0.821273
# 1   0.442356    0.820907
# 2   0.444166    0.820517
# 3   0.446951    0.819938
# 4   0.441500    0.818507
# 5   0.443627    0.817381
# 6   0.450673    0.814722
# 7   0.456011    0.813415
# 8   0.455128    0.813324
# 9   0.458580    0.812176
# 10  0.459854    0.811717
# 11  0.462044    0.811219
# 12  0.465399    0.810706
# 13  0.467861    0.810421
# 14  0.468103    0.809940
# 15  0.467160    0.808680
# 16  0.471170    0.807405
# 17  0.481208    0.803366
# 18  0.485542    0.803037
# 19  0.487507    0.802813

# %%
fig, ax = plt.subplots(figsize = (8,6))
plot_data = pd.DataFrame({
    'NumNodes' : [i for i in range(20)],
    'Degree' : df_community_d['nmi'],
    'Weighted Degree ': df_community_w['nmi'],
    'Random ': df_community_r['nmi']
})
colors_taratt = ['#761878', '#826fc9', '#b1c2f0' ]
sns.lineplot(x = 'NumNodes', y = 'value', hue = 'Targeting by', palette = colors_taratt, data = pd.melt(plot_data, ['NumNodes'], var_name= 'Targeting by'));
plt.suptitle('Change in Mutual Information', size = 15, weight ='bold')
ax.set_title('using targeted attacks', size = 13)
ax.set(xlabel = 'Number of deleted nodes', ylabel= 'Normalized Mutual Information');

if savefigs:
    plt.savefig('../figs/NMI.png', bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(figsize = (8,6))
plot_data = pd.DataFrame({
    'NumNodes' : [i for i in range(20)],
    'Degree Modularity' : df_community_d['modularity'],
    'Weighted Degree Modularity': df_community_w['modularity'],
    'Random Modularity': df_community_r['modularity']
})
colors_taratt = ['#761878', '#826fc9', '#b1c2f0' ]
sns.lineplot(x = 'NumNodes', y = 'value', hue = 'Targeting by', palette = colors_taratt, data = pd.melt(plot_data, ['NumNodes'], var_name= 'Targeting by'));
plt.suptitle('Change in Modularity', size = 15, weight ='bold')
ax.set_title('using targeted attacks', size = 13)
ax.set(xlabel = 'Number of deleted nodes', ylabel= 'Modularity');

if savefigs:
    plt.savefig('../figs/Modularity.png', bbox_inches = 'tight')

# %%
fig, axes = plt.subplots(11,2, figsize = (15, 35))

for i, label in enumerate(df_homophily_d.columns.tolist()):
    plot_data = pd.DataFrame({
        'NumNodes' : [i for i in range(20)],
        'Degree' : df_homophily_d[label],
        'Weighted Degree ': df_homophily_w[label],
        'Random ': df_homophily_r[label]
    })
    colors_taratt = ['#761878', '#826fc9', '#b1c2f0' ]
    sns.lineplot(x = 'NumNodes', y = 'value', hue = 'Targeting by', palette = colors_taratt, data = pd.melt(plot_data, ['NumNodes'], var_name= 'Targeting by'), ax = axes.flat[i]);
    axes.flat[i].set_title(f'Homophily of {label}', size = 13)
    if i % 2 == 0:
        axes.flat[i].set(ylabel= 'Homophily', xlabel = '');
    else:
        axes.flat[i].set(ylabel = '', xlabel = '')
axes.flat[20].set_xlabel('Number of deleted nodes')
axes.flat[21].set_xlabel('Number of deleted nodes')
plt.tight_layout();

if savefigs:
    plt.savefig('../figs/Homophily.png', bbox_inches = 'tight')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ae90e520-efbc-47c2-a035-acfb4219bc01' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
